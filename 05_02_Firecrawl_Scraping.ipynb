# %% [markdown]
# <a href="https://colab.research.google.com/github/towardsai/ai-tutor-rag-system/blob/main/notebooks/Firecrawl_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Install the requirements

# %%
# !pip install -q llama-index==0.12.48 llama-index-readers-web==0.3.7 openai==1.107.0 jedi==0.19.2 firecrawl-py==1.15.0
# Out:
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 50.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.8/96.8 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 951.0/951.0 kB 40.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 96.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.3/303.3 kB 17.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 MB 18.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 87.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.2/499.2 kB 25.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.4/144.4 kB 8.4 MB/s eta 0:00:00
#   Building wheel for html2text (setup.py) ... done
#   Building wheel for tinysegmenter (setup.py) ... done
#   Building wheel for spider-client (setup.py) ... done
#   Building wheel for feedfinder2 (setup.py) ... done
#   Building wheel for jieba3k (setup.py) ... done
#   Building wheel for sgmllib3k (setup.py) ... done

# %% [markdown]
# ### SET THE ENVIRONMENT VARIABLES

# %%
import os
# os.environ["OPENAI_API_KEY"] = "<OPENAI_API_KEY>"
# FIRECRAWL_API_KEY = "<FIRECRAWL_API_KEY>"

# from google.colab import userdata
# os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
# os.environ["FIRECRAWL_API_KEY"] = userdata.get('FIRECRAWL_API_KEY')

# FIRECRAWL_API_KEY = userdata.get('FIRECRAWL_API_KEY')

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # SCRAPE WITH FIRECRAWL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## IMPORT THE FIRECRAWL WEBREADER
#
# Firecrawl allows you to turn entire websites into LLM-ready markdown
#
# Get the API key here
# https://www.firecrawl.dev/app/api-keys

# %% [markdown]
# ### Example 1: Direct URL Scraping with FirecrawlWebReader

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# from llama_index.readers.web import FireCrawlWebReader

# # using firecrawl to crawl a website
# firecrawl_reader = FireCrawlWebReader(
#     api_key=os.getenv("FIRECRAWL_API_KEY"),  # Replace with your actual API key from https://www.firecrawl.dev/
#     mode="scrape",
#     params={'formats':["markdown", "html"]},
# )

# documents = firecrawl_reader.load_data(url="https://towardsai.net/")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 10
#       3 # using firecrawl to crawl a website
#       4 firecrawl_reader = FireCrawlWebReader(
#       5     api_key=os.getenv("FIRECRAWL_API_KEY"),  # Replace with your actual API key from https://www.firecrawl.dev/
#       6     mode="scrape",
#       7     params={'formats':["markdown", "html"]},
#       8 )
# ---> 10 documents = firecrawl_reader.load_data(url="https://towardsai.net/")
#
# File c:\DROPBOX\Документы\Карзановы\Андрей\__CHALLENGES\AI_Full_Stack_Developer\.venv\Lib\site-packages\llama_index\readers\web\firecrawl_web\base.py:81, in FireCrawlWebReader.load_data(self, url, query)
#      78 documents = []
#      80 if self.mode == "scrape":
# ---> 81     firecrawl_docs = self.firecrawl.scrape_url(url, params=self.params)
#      82     documents.append(
#      83         Document(
#      84             text=firecrawl_docs.get("markdown", ""),
#      85             metadata=firecrawl_docs.get("metadata", {}),
#      86         )
#      87     )
#      88 elif self.mode == "crawl":
#
# AttributeError: 'Firecrawl' object has no attribute 'scrape_url'

# %%
print(dir(app))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_v1_client', '_v2_client', 'active_crawls', 'api_key', 'api_url', 'batch_scrape', 'cancel_batch_scrape', 'cancel_crawl', 'crawl', 'crawl_params_preview', 'extract', 'get_active_crawls', 'get_batch_scrape_errors', 'get_batch_scrape_status', 'get_concurrency', 'get_crawl_errors', 'get_crawl_status', 'get_credit_usage', 'get_extract_status', 'get_queue_status', 'get_token_usage', 'map', 'scrape', 'search', 'start_batch_scrape', 'start_crawl', 'start_extract', 'v1', 'v2', 'watcher']

# %%
from firecrawl import FirecrawlApp
from llama_index.core import Document

# Initialize Firecrawl
app = FirecrawlApp(api_key=os.getenv("FIRECRAWL_API_KEY"))

# Scrape the URL
scraped_data = app.scrape(url="https://towardsai.net/", formats=["markdown", "html"])

# %%
print(scraped_data)
print(dir(scraped_data))
# Out:
# markdown='- [Latest](https://towardsai.net/p/)\n- [Trends](https://medium.com/towards-artificial-intelligence/trending)\n- [Shop](https://gumroad.com/towardsai)\n\n[Google News](https://news.google.com/publications/CAAqBwgKMNiLmgswgpayAw)[Medium](https://pub.towardsai.net/)[Linkedin](https://linkedin.com/company/towards-artificial-intelligence)[Twitter](https://twitter.com/towards_ai?lang=en)[Facebook](https://www.facebook.com/towardsAl/)[Instagram](https://instagram.com/towards_ai/)[Github](https://github.com/towardsai)[RSS Feed](http://feeds.feedburner.com/towards-ai)[Email us](mailto:pub@towardsai.net)\n\nName: Towards AI\nLegal Name: Towards AI, Inc.\nDescription: Towards AI is the world\'s leading artificial intelligence (AI) and technology publication. Read by thought-leaders and decision-makers around the world.\nPhone Number: +1-650-246-9381\nEmail: pub@towardsai.net\n\n228 Park Avenue SouthNew York,\nNY10003United States\n\nWebsite: [https://towardsai.net/](https://towardsai.net/)\nPublisher: [https://towardsai.net/#publisher](https://towardsai.net/#publisher)\nDiversity Policy: [https://towardsai.net/about](https://towardsai.net/about)\nEthics Policy: [https://towardsai.net/about](https://towardsai.net/about)\nMasthead: [https://towardsai.net/about](https://towardsai.net/about)\n\nName: Towards AI\nLegal Name: Towards AI, Inc.\nDescription: Towards AI is the world\'s leading artificial intelligence (AI) and technology publication.\nFounders:\nRoberto Iriondo,\n[Website](https://www.robertoiriondo.com/),\nJob Title: Co-founder and Advisor\nWorks for: Towards AI, Inc.\nFollow Roberto:\n[X](https://x.com/@robiriondo),\n[LinkedIn](https://www.linkedin.com/in/robiriondo),\n[GitHub](https://github.com/robiriondo),\n[Google Scholar](https://scholar.google.com/citations?user=dTn7NEcAAAAJ),\n[Towards AI Profile](https://towardsai.net/p/author/robiriondo),\n[Medium](https://medium.com/@robiriondo),\n[ML@CMU](https://www.ml.cmu.edu/robiriondo),\n[FreeCodeCamp](https://www.freecodecamp.org/news/author/robiriondo/),\n[Crunchbase](https://www.crunchbase.com/person/roberto-iriondo),\n[Bloomberg](https://www.bloomberg.com/profile/person/22994840),\n[Roberto Iriondo, Generative AI Lab](https://roberto.generativeailab.org/),\n[Generative AI Lab](https://generativeailab.org/) [VeloxTrend](https://veloxtrend.com/) [Ultrarix Capital Partners](https://ultrarix.com/)Denis Piffaretti,\nJob Title: Co-founder\nWorks for: Towards AI, Inc.Louie Peters,\nJob Title: Co-founder\nWorks for: Towards AI, Inc.Louis-François Bouchard,\nJob Title: Co-founder\nWorks for: Towards AI, Inc.\n\nCover:\n\n\n![Towards AI Cover](https://b3688296.smushcdn.com/3688296/wp-content/uploads/2024/09/towards-ai-og-graph.jpg?lossy=0&strip=1&webp=1)\n\nLogo:\n\n\n![Towards AI Logo](https://b3688296.smushcdn.com/3688296/wp-content/uploads/2019/05/towards-ai-square-circle-png.png?lossy=0&strip=1&webp=1)\n\nAreas Served: Worldwide\nAlternate Name: Towards AI, Inc.\nAlternate Name: Towards AI Co.\nAlternate Name: towards ai\nAlternate Name: towardsai\nAlternate Name: towards.ai\nAlternate Name: tai\nAlternate Name: toward ai\nAlternate Name: toward.ai\nAlternate Name: Towards AI, Inc.\nAlternate Name: towardsai.net\nAlternate Name: pub.towardsai.net\n\nFollow us on:\n[Facebook](https://www.facebook.com/towardsAl/ "Facebook") [X](https://x.com/towards_ai "X") [LinkedIn](https://www.linkedin.com/company/towards-artificial-intelligence "LinkedIn") [Instagram](https://www.instagram.com/towards_ai/ "Instagram") [Youtube](https://www.youtube.com/channel/UCQNjFuhOJM1YqFTPY1Q_kYQ "Youtube") [Github](https://github.com/towardsai "Github") [Google My Business](https://local.google.com/place?id=4955254490173856159&use=srp&ved=1t%3A65428&_ga=2.191706990.559569912.1635283323-985655235.1633987376#fpstate=lie "Google my Business") [Google Search](https://www.google.com/search?ved=1t:65428&_ga=2.191706990.559569912.1635283323-985655235.1633987376&q=Towards+AI&ludocid=4955254490173856159&lsi ...
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__class_vars__', '__copy__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__fields__', '__fields_set__', '__firstlineno__', '__format__', '__ge__', '__get_pydantic_core_schema__', '__get_pydantic_json_schema__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__pretty__', '__private_attributes__', '__pydantic_complete__', '__pydantic_computed_fields__', '__pydantic_core_schema__', '__pydantic_custom_init__', '__pydantic_decorators__', '__pydantic_extra__', '__pydantic_fields__', '__pydantic_fields_set__', '__pydantic_generic_metadata__', '__pydantic_init_subclass__', '__pydantic_on_complete__', '__pydantic_parent_namespace__', '__pydantic_post_init__', '__pydantic_private__', '__pydantic_root_model__', '__pydantic_serializer__', '__pydantic_setattr_handlers__', '__pydantic_validator__', '__reduce__', '__reduce_ex__', '__replace__', '__repr__', '__repr_args__', '__repr_name__', '__repr_recursion__', '__repr_str__', '__rich_repr__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_calculate_keys', '_copy_and_set_values', '_get_value', '_iter', '_setattr_handler', 'actions', 'change_tracking', 'construct', 'copy', 'dict', 'from_orm', 'html', 'images', 'json', 'links', 'markdown', 'metadata', 'metadata_dict', 'metadata_typed', 'model_computed_fields', 'model_config', 'model_construct', 'model_copy', 'model_dump', 'model_dump_json', 'model_extra', 'model_fields', 'model_fields_set', 'model_json_schema', 'model_parametrized_name', 'model_post_init', 'model_rebuild', 'model_validate', 'model_validate_json', 'model_validate_strings', 'parse_file', 'parse_obj', 'parse_raw', 'raw_html', 'schema', 'schema_json', 'screenshot', 'summary', 'update_forward_refs', 'validate', 'warning']

# %%
# Convert to LlamaIndex Document
documents = [Document(
    text=scraped_data.markdown,
    metadata=scraped_data.metadata
)]

# %%
print(documents[0].text[:500])  # Print first 500 characters of the document text
print(documents[0].metadata)     # Print the metadata of the document
# Out:
# - [Latest](https://towardsai.net/p/)
# - [Trends](https://medium.com/towards-artificial-intelligence/trending)
# - [Shop](https://gumroad.com/towardsai)
#
# [Google News](https://news.google.com/publications/CAAqBwgKMNiLmgswgpayAw)[Medium](https://pub.towardsai.net/)[Linkedin](https://linkedin.com/company/towards-artificial-intelligence)[Twitter](https://twitter.com/towards_ai?lang=en)[Facebook](https://www.facebook.com/towardsAl/)[Instagram](https://instagram.com/towards_ai/)[Github](https://github.co
# {'title': 'Towards AI', 'description': "Master AI with Towards AI. We offer practical AI Engineering courses, corporate AI bootcamps, and LLM development consultancy for individuals and companies., Towards AI's thoughts on the week's biggest AI developments. \nAll major AI news, models, tools and papers covered. \nRead by over 130,000 AI Practitioners, Industry Professionals and Students. Click to read Towards AI Newsletter, a Substack publication.", 'url': 'https://towardsai.net/', 'language': 'en-US', 'keywords': None, 'robots': 'max-image-preview:large, noindex', 'og_title': 'Towards AI', 'og_description': 'Master AI with Towards AI. We offer practical AI Engineering courses, corporate AI bootcamps, and LLM development consultancy for individuals and companies.', 'og_url': 'https://towardsai.net/', 'og_image': 'https://towardsai.net/wp-content/uploads/2024/09/towards-ai-og-graph.jpg', 'og_audio': None, 'og_determiner': None, 'og_locale': None, 'og_locale_alternate': None, 'og_site_name': None, 'og_video': None, 'favicon': 'https://b3688296.smushcdn.com/3688296/wp-content/uploads/2019/05/cropped-towards-ai-square-circle-png-32x32.png?lossy=0&strip=1&webp=1', 'dc_terms_created': None, 'dc_date_created': None, 'dc_date': None, 'dc_terms_type': None, 'dc_type': None, 'dc_terms_audience': None, 'dc_terms_subject': None, 'dc_subject': None, 'dc_description': None, 'dc_terms_keywords': None, 'modified_time': None, 'published_time': None, 'article_tag': None, 'article_section': None, 'source_url': 'https://towardsai.net/', 'status_code': 200, 'scrape_id': '68b88c8c-4bc8-4608-8388-021e3dd9192e', 'num_pages': None, 'content_type': 'text/html; charset=UTF-8', 'proxy_used': 'basic', 'cache_state': 'hit', 'cached_at': '2025-10-19T16:07:12.458Z', 'credits_used': 1, 'error': None}

# %%
from llama_index.core import VectorStoreIndex, Settings
from llama_index.core.node_parser import SentenceSplitter

# To increase chunk size globally
# Settings.chunk_size = 2048  # or even larger like 4096
# Settings.chunk_overlap = 200


# node parser with larger chunk size only for this index
node_parser = SentenceSplitter(
    chunk_size=2048,
    chunk_overlap=200,
)

index = VectorStoreIndex.from_documents(documents, transformations=[node_parser])
query_engine = index.as_query_engine()

# %%
res = query_engine.query("What is towards AI aim?")

print(res.response)
# Out:
# Towards AI aims to make AI and ML accessible to all by offering practical AI Engineering courses, corporate AI bootcamps, and LLM development consultancy for individuals and companies.

# %%
res.source_nodes[0].metadata
# Out:
# {'title': 'Towards AI',
#  'description': "Master AI with Towards AI. We offer practical AI Engineering courses, corporate AI bootcamps, and LLM development consultancy for individuals and companies., Towards AI's thoughts on the week's biggest AI developments. \nAll major AI news, models, tools and papers covered. \nRead by over 130,000 AI Practitioners, Industry Professionals and Students. Click to read Towards AI Newsletter, a Substack publication.",
#  'url': 'https://towardsai.net/',
#  'language': 'en-US',
#  'keywords': None,
#  'robots': 'max-image-preview:large, noindex',
#  'og_title': 'Towards AI',
#  'og_description': 'Master AI with Towards AI. We offer practical AI Engineering courses, corporate AI bootcamps, and LLM development consultancy for individuals and companies.',
#  'og_url': 'https://towardsai.net/',
#  'og_image': 'https://towardsai.net/wp-content/uploads/2024/09/towards-ai-og-graph.jpg',
#  'og_audio': None,
#  'og_determiner': None,
#  'og_locale': None,
#  'og_locale_alternate': None,
#  'og_site_name': None,
#  'og_video': None,
#  'favicon': 'https://b3688296.smushcdn.com/3688296/wp-content/uploads/2019/05/cropped-towards-ai-square-circle-png-32x32.png?lossy=0&strip=1&webp=1',
#  'dc_terms_created': None,
#  'dc_date_created': None,
#  'dc_date': None,
#  'dc_terms_type': None,
#  'dc_type': None,
#  'dc_terms_audience': None,
#  'dc_terms_subject': None,
#  'dc_subject': None,
#  'dc_description': None,
#  'dc_terms_keywords': None,
#  'modified_time': None,
#  'published_time': None,
#  'article_tag': None,
#  'article_section': None,
#  'source_url': 'https://towardsai.net/',
#  'status_code': 200,
#  'scrape_id': '68b88c8c-4bc8-4608-8388-021e3dd9192e',
#  'num_pages': None,
#  'content_type': 'text/html; charset=UTF-8',
#  'proxy_used': 'basic',
#  'cache_state': 'hit',
#  'cached_at': '2025-10-19T16:07:12.458Z',
#  'credits_used': 1,
#  'error': None}

# %%
print("-----------------")
# Show the retrieved nodes
for src in res.source_nodes:
  print("Node ID\t", src.node_id)
  print("Title\t", src.metadata['title'])
  print("URL\t", src.metadata['source_url'])
  print("Score\t", src.score)
  print("Description\t", src.metadata.get("description"))
  print("-_"*20)
# Out:
# -----------------
# Node ID	 3daeed50-1f87-49a4-a0ef-c5fdbd2d4958
# Title	 Towards AI
# URL	 https://towardsai.net/
# Score	 0.883381100021065
# Description	 Master AI with Towards AI. We offer practical AI Engineering courses, corporate AI bootcamps, and LLM development consultancy for individuals and companies., Towards AI's thoughts on the week's biggest AI developments.
# All major AI news, models, tools and papers covered.
# Read by over 130,000 AI Practitioners, Industry Professionals and Students. Click to read Towards AI Newsletter, a Substack publication.
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# Node ID	 baa7ee67-d279-4d83-a20b-9be0b0960ce8
# Title	 Towards AI
# URL	 https://towardsai.net/
# Score	 0.8827601706237285
# Description	 Master AI with Towards AI. We offer practical AI Engineering courses, corporate AI bootcamps, and LLM development consultancy for individuals and companies., Towards AI's thoughts on the week's biggest AI developments.
# All major AI news, models, tools and papers covered.
# Read by over 130,000 AI Practitioners, Industry Professionals and Students. Click to read Towards AI Newsletter, a Substack publication.
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # CRAWL A WEBSITE

# %% [markdown]
# ## Load The CSV
#
# CSV contains the list of tools and url of the page which we use to get information about the tool.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
import csv

# Google Sheets file URL (CSV export link)
url = 'https://docs.google.com/spreadsheets/d/1gHB-aQJGt9Nl3cyOP2GorAkBI_Us2AqkYnfqrmejStc/export?format=csv'

# Send a GET request to fetch the CSV file
response = requests.get(url)

response_list = []
# Check if the request was successful
if response.status_code == 200:
    # Decode the content to a string
    content = response.content.decode('utf-8')

    # Use the csv.DictReader to read the content as a dictionary
    csv_reader = csv.DictReader(content.splitlines(), delimiter=',')
    response_list = [row for row in csv_reader]
else:
    print(f"Failed to retrieve the file: {response.status_code}")

# %%
len(response_list)
# Out:
# 371

# %%
response_list[0]
# Out:
# {'Name': 'Microsoft Azure AI Platform',
#  'Tool Type': 'Cloud Platform',
#  'Parent': '',
#  'Company': '',
#  'Description': 'Cloud-based environment for training, deploying, automating, managing, and tracking ML models',
#  'Category': 'Cloud ML Platform',
#  'URL': 'https://azure.microsoft.com/en-us/products/machine-learning',
#  'Is a direct URL company /tool website?': 'Yes',
#  '': ''}

# %%
import random

start_index = random.randint(0, len(response_list) - 3)
website_list = response_list[start_index:start_index+10] # Crawling 10 websites only.

# %%
import pprint
print("CSV data")
pprint.pprint(website_list)
# Out:
# CSV data
# [{'': '',
#   'Category': 'Workflow Management',
#   'Company': '',
#   'Description': 'Python package for building complex pipelines of batch jobs',
#   'Is a direct URL company /tool website?': 'No',
#   'Name': 'Luigi',
#   'Parent': '',
#   'Tool Type': 'Library',
#   'URL': 'https://luigi.readthedocs.io/en/stable/workflows.html'},
#  {'': '',
#   'Category': 'Data Serialization',
#   'Company': '',
#   'Description': 'ORM/ODM/framework-agnostic library for converting complex '
#                  'datatypes to and from native Python datatypes',
#   'Is a direct URL company /tool website?': 'Yes',
#   'Name': 'Marshmallow',
#   'Parent': '',
#   'Tool Type': 'Library',
#   'URL': 'https://marshmallow.readthedocs.io/en/stable/'},
#  {'': '',
#   'Category': 'Data Visualization',
#   'Company': '',
#   'Description': 'Low level graph plotting library in python that serves as a '
#                  'visualization utility',
#   'Is a direct URL company /tool website?': 'Yes',
#   'Name': 'Matplotlib',
#   'Parent': '',
#   'Tool Type': 'Library',
#   'URL': 'https://matplotlib.org/'},
#  {'': '',
#   'Category': 'Data Generation',
#   'Company': '',
#   'Description': 'High-performance fake data generator',
#   'Is a direct URL company /tool website?': 'Yes',
#   'Name': 'Mimesis',
#   'Parent': '',
#   'Tool Type': 'Library',
#   'URL': 'https://mimesis.name/en/v13.1.0/'},
#  {'': '',
#   'Category': 'Machine Learning',
#   'Company': '',
#   'Description': "Library of extension and helper modules for Python's data "
#                  'science stack',
#   'Is a direct URL company /tool website?': 'No',
#   'Name': 'MLxtend',
#   'Parent': '',
#   'Tool Type': 'Library',
#   'URL': 'https://rasbt.github.io/mlxtend/'},
#  {'': '',
#   'Category': 'Big Data Processing',
#   'Company': '',
#   'Description': 'Speed up your Pandas workflows by changing a single line of '
#                  'code',
#   'Is a direct URL company /tool website?': 'Yes',
#   'Name': 'Modin',
#   'Parent': '',
#   'Tool Type': 'Library',
#   'URL': 'https://modin.readthedocs.io/en/stable/getting_started/why_modin/out_of_core.html'},
#  {'': '',
#   'Category': 'Graph Analysis',
#   'Company': '',
#   'Description': 'Python package for the creation, manipulation, and study of '
#                  'complex networks',
#   'Is a direct URL company /tool website?': 'Yes',
#   'Name': 'NetworkX',
#   'Parent': '',
#   'Tool Type': 'Library',
#   'URL': 'https://networkx.org/'},
#  {'': '',
#   'Category': 'Optimization',
#   'Company': '',
#   'Description': 'Gradient-free optimization platform',
#   'Is a direct URL company /tool website?': 'No',
#   'Name': 'Nevergrad',
#   'Parent': '',
#   'Tool Type': 'Library',
#   'URL': 'https://facebookresearch.github.io/nevergrad/'},
#  {'': '',
#   'Category': 'Programming Language',
#   'Company': '',
#   'Description': 'A suite of libraries and programs for symbolic and '
#                  'statistical natural language processing for English written '
#                  'in the Python programming language',
#   'Is a direct URL company /tool website?': 'Yes',
#   'Name': 'NLTK',
#   'Parent': '',
#   'Tool Type': 'Library',
#   'URL': 'https://www.nltk.org/'},
#  {'': '',
#   'Category': 'Similarity Search',
#   'Company': '',
#   'Description': 'Non-Metric Space Library, an efficient similarity search '
#                  'library',
#   'Is a direct URL company /tool website?': 'No',
#   'Name': 'NMSLIB',
#   'Parent': '',
#   'Tool Type': 'Library',
#   'URL': 'https://pypi.org/project/nmslib/'}]

# %% [markdown]
# ## Initialize the Firecrawl

# %%
import os
from firecrawl import FirecrawlApp
app = FirecrawlApp(api_key=os.getenv("FIRECRAWL_API_KEY"))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import time

# Crawl websites and handle responses
url_response = {}
crawl_per_min = 1  # Max crawl per minute

# Track crawls
crawled_websites = 0
scraped_pages = 0

for i, website_dict in enumerate(website_list):
    url = website_dict.get('URL')
    print(f"Crawling: {url}")

    try:
        response = app.crawl(
            url=url,
            limit=5,  # Limit pages to scrape per site.
            scrape_options={'formats': ['markdown', 'html']}
        )
        crawled_websites += 1

    except Exception as exc:
        print(f"Failed to fetch {url} -> {exc}")
        continue

    # Store the scraped data and associated info in the response dict
    url_response[url] = {
        "scraped_data": response.data,
        "csv_data": website_dict
    }

    # Pause to comply with crawl per minute limit for free version its 1 crawl per minute
    if i!=len(website_list) and (i + 1) % crawl_per_min == 0:
        print("Pausing for 1 minute to comply with crawl limit...")
        time.sleep(60)  # Pause for 1 minute after every crawl
# Out:
# Crawling: https://luigi.readthedocs.io/en/stable/workflows.html
# Pausing for 1 minute to comply with crawl limit...
# Crawling: https://marshmallow.readthedocs.io/en/stable/
# Pausing for 1 minute to comply with crawl limit...
# Crawling: https://matplotlib.org/
# Pausing for 1 minute to comply with crawl limit...
# Crawling: https://mimesis.name/en/v13.1.0/
# Pausing for 1 minute to comply with crawl limit...
# Crawling: https://rasbt.github.io/mlxtend/
# Pausing for 1 minute to comply with crawl limit...
# Crawling: https://modin.readthedocs.io/en/stable/getting_started/why_modin/out_of_core.html
# Pausing for 1 minute to comply with crawl limit...
# Crawling: https://networkx.org/
# Pausing for 1 minute to comply with crawl limit...
# Crawling: https://facebookresearch.github.io/nevergrad/
# Pausing for 1 minute to comply with crawl limit...
# Crawling: https://www.nltk.org/
# Pausing for 1 minute to comply with crawl limit...
# Crawling: https://pypi.org/project/nmslib/
# Pausing for 1 minute to comply with crawl limit...

# %%
website_dict
# Out:
# {'Name': 'NMSLIB',
#  'Tool Type': 'Library',
#  'Parent': '',
#  'Company': '',
#  'Description': 'Non-Metric Space Library, an efficient similarity search library',
#  'Category': 'Similarity Search',
#  'URL': 'https://pypi.org/project/nmslib/',
#  'Is a direct URL company /tool website?': 'No',
#  '': ''}

# %%
# Crawling: https://luigi.readthedocs.io/en/stable/workflows.html
url_response_0 = next(iter(url_response.items()))
url_response_0
# Out:
# ('https://luigi.readthedocs.io/en/stable/workflows.html',
#  {'scraped_data': [Document(markdown='# Building workflows [¶](https://luigi.readthedocs.io/en/stable/workflows.html\\#building-workflows "Link to this heading")\n\nThere are two fundamental building blocks of Luigi -\nthe [`Task`](https://luigi.readthedocs.io/en/stable/api/luigi.task.html#luigi.task.Task "luigi.task.Task") class and the [`Target`](https://luigi.readthedocs.io/en/stable/api/luigi.target.html#luigi.target.Target "luigi.target.Target") class.\nBoth are abstract classes and expect a few methods to be implemented.\nIn addition to those two concepts,\nthe [`Parameter`](https://luigi.readthedocs.io/en/stable/api/luigi.parameter.html#luigi.parameter.Parameter "luigi.parameter.Parameter") class is an important concept that governs how a Task is run.\n\n## Target [¶](https://luigi.readthedocs.io/en/stable/workflows.html\\#target "Link to this heading")\n\nThe [`Target`](https://luigi.readthedocs.io/en/stable/api/luigi.target.html#luigi.target.Target "luigi.target.Target") class corresponds to a file on a disk,\na file on HDFS or some kind of a checkpoint, like an entry in a database.\nActually, the only method that Targets have to implement is the _exists_\nmethod which returns True if and only if the Target exists.\n\nIn practice, implementing Target subclasses is rarely needed.\nLuigi comes with a toolbox of several useful Targets.\nIn particular, `LocalTarget` and [`HdfsTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.hdfs.target.html#luigi.contrib.hdfs.target.HdfsTarget "luigi.contrib.hdfs.target.HdfsTarget"),\nbut there is also support for other file systems:\n[`luigi.contrib.s3.S3Target`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.s3.html#luigi.contrib.s3.S3Target "luigi.contrib.s3.S3Target"),\n[`luigi.contrib.ssh.RemoteTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.ssh.html#luigi.contrib.ssh.RemoteTarget "luigi.contrib.ssh.RemoteTarget"),\n[`luigi.contrib.ftp.RemoteTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.ftp.html#luigi.contrib.ftp.RemoteTarget "luigi.contrib.ftp.RemoteTarget"),\n[`luigi.contrib.mysqldb.MySqlTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.mysqldb.html#luigi.contrib.mysqldb.MySqlTarget "luigi.contrib.mysqldb.MySqlTarget"),\n[`luigi.contrib.redshift.RedshiftTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.redshift.html#luigi.contrib.redshift.RedshiftTarget "luigi.contrib.redshift.RedshiftTarget"), and several more.\n\nMost of these targets, are file system-like.\nFor instance, `LocalTarget` and [`HdfsTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.hdfs.target.html#luigi.contrib.hdfs.target.HdfsTarget "luigi.contrib.hdfs.target.HdfsTarget") map to a file on the local drive or a file in HDFS.\nIn addition these also wrap the underlying operations to make them atomic.\nThey both implement the `open()` method which returns a stream object that\ncould be read ( `mode=\'r\'`) from or written to ( `mode=\'w\'`).\n\nLuigi comes with Gzip support by providing `format=format.Gzip`.\nAdding support for other formats is pretty simple.\n\n## Task [¶](https://luigi.readthedocs.io/en/stable/workflows.html\\#task "Link to this heading")\n\nThe [`Task`](https://luigi.readthedocs.io/en/stable/api/luigi.task.html#luigi.task.Task "luigi.task.Task") class is a bit more conceptually interesting because this is\nwhere computation is done.\nThere are a few methods that can be implemented to alter its behavior,\nmost notably [`run()`](https://luigi.readthedocs.io/en/stable/api/luigi.task.html#luigi.task.Task.run "luigi.task.Task.run"), [`output()`](https://luigi.readthedocs.io/en/stable/api/luigi.task.html#luigi.task.Task.output "luigi.task.Task.output") and [`requires()`](https://luigi.readthedocs.io/en/stable/api/luigi.task.html#luigi.task.Task.requires "luigi.task.Task.requires").\n\nTasks consume Targets that were created by some other task. They usually also output targets:\n\n> ![Task and t ...
#   'csv_data': {'Name': 'Luigi',
#    'Tool Type': 'Library',
#    'Parent': '',
#    'Company': '',
#    'Description': 'Python package for building complex pipelines of batch jobs',
#    'Category': 'Workflow Management',
#    'URL': 'https://luigi.readthedocs.io/en/stable/workflows.html',
#    'Is a direct URL company /tool website?': 'No',
#    '': ''}})

# %%
print(type(url_response_0[1]))
# Out:
# <class 'dict'>

# %%
print(url_response_0[1].keys())
# Out:
# dict_keys(['scraped_data', 'csv_data'])

# %% [markdown]
# ## Create  llamaindex documents from the scraped content

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from llama_index.core import Document
documents = []

# This nested structure enables the code to systematically handle each website, processing all pages for each site individually. For each page, it creates a distinct Document object, merging the scraped content with relevant metadata from the CSV file.

# The outer loop, for url, scraped_content in url_response.items(): iterates through each crawled URL, retrieving its scraped content and associated CSV data.
for _, scraped_content in url_response.items():
    csv_data = scraped_content["csv_data"]
    scraped_results = scraped_content["scraped_data"]

    # for scraped_site_dict in scraped_results: # OBSOLETE LOOP

    #  Within this, the inner loop for result in scraped_results: processes each scraped page related to the URL, accommodating cases where a single URL has multiple pages.
    for result in scraped_results:
        markdown_content = result.markdown
        title = result.metadata.title
        url = result.metadata.source_url
        documents.append(
            Document(
                text=markdown_content,
                metadata={
                    "title": title,
                    "url": url,
                    "description": csv_data.get("Description"),
                    "category": csv_data.get("Category")
                }
            )
        )

# %%
result
# Out:
# Document(markdown='# Building workflows [¶](https://luigi.readthedocs.io/en/stable/workflows.html\\#building-workflows "Link to this heading")\n\nThere are two fundamental building blocks of Luigi -\nthe [`Task`](https://luigi.readthedocs.io/en/stable/api/luigi.task.html#luigi.task.Task "luigi.task.Task") class and the [`Target`](https://luigi.readthedocs.io/en/stable/api/luigi.target.html#luigi.target.Target "luigi.target.Target") class.\nBoth are abstract classes and expect a few methods to be implemented.\nIn addition to those two concepts,\nthe [`Parameter`](https://luigi.readthedocs.io/en/stable/api/luigi.parameter.html#luigi.parameter.Parameter "luigi.parameter.Parameter") class is an important concept that governs how a Task is run.\n\n## Target [¶](https://luigi.readthedocs.io/en/stable/workflows.html\\#target "Link to this heading")\n\nThe [`Target`](https://luigi.readthedocs.io/en/stable/api/luigi.target.html#luigi.target.Target "luigi.target.Target") class corresponds to a file on a disk,\na file on HDFS or some kind of a checkpoint, like an entry in a database.\nActually, the only method that Targets have to implement is the _exists_\nmethod which returns True if and only if the Target exists.\n\nIn practice, implementing Target subclasses is rarely needed.\nLuigi comes with a toolbox of several useful Targets.\nIn particular, `LocalTarget` and [`HdfsTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.hdfs.target.html#luigi.contrib.hdfs.target.HdfsTarget "luigi.contrib.hdfs.target.HdfsTarget"),\nbut there is also support for other file systems:\n[`luigi.contrib.s3.S3Target`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.s3.html#luigi.contrib.s3.S3Target "luigi.contrib.s3.S3Target"),\n[`luigi.contrib.ssh.RemoteTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.ssh.html#luigi.contrib.ssh.RemoteTarget "luigi.contrib.ssh.RemoteTarget"),\n[`luigi.contrib.ftp.RemoteTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.ftp.html#luigi.contrib.ftp.RemoteTarget "luigi.contrib.ftp.RemoteTarget"),\n[`luigi.contrib.mysqldb.MySqlTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.mysqldb.html#luigi.contrib.mysqldb.MySqlTarget "luigi.contrib.mysqldb.MySqlTarget"),\n[`luigi.contrib.redshift.RedshiftTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.redshift.html#luigi.contrib.redshift.RedshiftTarget "luigi.contrib.redshift.RedshiftTarget"), and several more.\n\nMost of these targets, are file system-like.\nFor instance, `LocalTarget` and [`HdfsTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.hdfs.target.html#luigi.contrib.hdfs.target.HdfsTarget "luigi.contrib.hdfs.target.HdfsTarget") map to a file on the local drive or a file in HDFS.\nIn addition these also wrap the underlying operations to make them atomic.\nThey both implement the `open()` method which returns a stream object that\ncould be read ( `mode=\'r\'`) from or written to ( `mode=\'w\'`).\n\nLuigi comes with Gzip support by providing `format=format.Gzip`.\nAdding support for other formats is pretty simple.\n\n## Task [¶](https://luigi.readthedocs.io/en/stable/workflows.html\\#task "Link to this heading")\n\nThe [`Task`](https://luigi.readthedocs.io/en/stable/api/luigi.task.html#luigi.task.Task "luigi.task.Task") class is a bit more conceptually interesting because this is\nwhere computation is done.\nThere are a few methods that can be implemented to alter its behavior,\nmost notably [`run()`](https://luigi.readthedocs.io/en/stable/api/luigi.task.html#luigi.task.Task.run "luigi.task.Task.run"), [`output()`](https://luigi.readthedocs.io/en/stable/api/luigi.task.html#luigi.task.Task.output "luigi.task.Task.output") and [`requires()`](https://luigi.readthedocs.io/en/stable/api/luigi.task.html#luigi.task.Task.requires "luigi.task.Task.requires").\n\nTasks consume Targets that were created by some other task. They usually also output targets:\n\n> ![Task and targets](https://lui ...

# %%
len(documents)
# Out:
# 38

# %%
documents[0]
# Out:
# Document(id_='01efe0f4-a4c8-4198-953e-d3360a3dcc34', embedding=None, metadata={'title': 'Building workflows — Luigi 3.6.0 documentation', 'url': 'https://luigi.readthedocs.io/en/stable/workflows.html', 'description': 'Python package for building complex pipelines of batch jobs', 'category': 'Workflow Management'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# Building workflows [¶](https://luigi.readthedocs.io/en/stable/workflows.html\\#building-workflows "Link to this heading")\n\nThere are two fundamental building blocks of Luigi -\nthe [`Task`](https://luigi.readthedocs.io/en/stable/api/luigi.task.html#luigi.task.Task "luigi.task.Task") class and the [`Target`](https://luigi.readthedocs.io/en/stable/api/luigi.target.html#luigi.target.Target "luigi.target.Target") class.\nBoth are abstract classes and expect a few methods to be implemented.\nIn addition to those two concepts,\nthe [`Parameter`](https://luigi.readthedocs.io/en/stable/api/luigi.parameter.html#luigi.parameter.Parameter "luigi.parameter.Parameter") class is an important concept that governs how a Task is run.\n\n## Target [¶](https://luigi.readthedocs.io/en/stable/workflows.html\\#target "Link to this heading")\n\nThe [`Target`](https://luigi.readthedocs.io/en/stable/api/luigi.target.html#luigi.target.Target "luigi.target.Target") class corresponds to a file on a disk,\na file on HDFS or some kind of a checkpoint, like an entry in a database.\nActually, the only method that Targets have to implement is the _exists_\nmethod which returns True if and only if the Target exists.\n\nIn practice, implementing Target subclasses is rarely needed.\nLuigi comes with a toolbox of several useful Targets.\nIn particular, `LocalTarget` and [`HdfsTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.hdfs.target.html#luigi.contrib.hdfs.target.HdfsTarget "luigi.contrib.hdfs.target.HdfsTarget"),\nbut there is also support for other file systems:\n[`luigi.contrib.s3.S3Target`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.s3.html#luigi.contrib.s3.S3Target "luigi.contrib.s3.S3Target"),\n[`luigi.contrib.ssh.RemoteTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.ssh.html#luigi.contrib.ssh.RemoteTarget "luigi.contrib.ssh.RemoteTarget"),\n[`luigi.contrib.ftp.RemoteTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.ftp.html#luigi.contrib.ftp.RemoteTarget "luigi.contrib.ftp.RemoteTarget"),\n[`luigi.contrib.mysqldb.MySqlTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.mysqldb.html#luigi.contrib.mysqldb.MySqlTarget "luigi.contrib.mysqldb.MySqlTarget"),\n[`luigi.contrib.redshift.RedshiftTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.redshift.html#luigi.contrib.redshift.RedshiftTarget "luigi.contrib.redshift.RedshiftTarget"), and several more.\n\nMost of these targets, are file system-like.\nFor instance, `LocalTarget` and [`HdfsTarget`](https://luigi.readthedocs.io/en/stable/api/luigi.contrib.hdfs.target.html#luigi.contrib.hdfs.target.HdfsTarget "luigi.contrib.hdfs.target.HdfsTarget") map to a file on the local drive or a file in HDFS.\nIn addition these also wrap the underlying operations to make them atomic.\nThey both implement the `open()` method which returns a stream object that\ncould be read ( `mode=\'r\'`) from or written to ( `mode=\'w\'`).\n\nLuigi comes with Gzip support by providing `format=format.Gzip`.\nAdding support for other formats is pretty simple.\n\n## Task [¶](https://luigi.readthedocs.io/en/stable/workflows.html\\#task "Link to this heading")\n\nThe [`Task`](https://luigi.readthedocs.io/en/stable/api/luigi.task.html#luigi.task.Task "luigi.task.Task") class is a bit more conceptually interesting because this is\nwhere computation is done.\nThere are a few methods that can be implemented to alter its behavior,\nmost notably [`run()`](https://luigi.readthedocs.io/en/stable/api/luigi.task.html#luigi.task.Task.run "luigi.task.Task.run"), [ ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Create The RAG Pipeline.

# %%
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core.node_parser import SentenceSplitter

Settings.llm = OpenAI(model="gpt-4o-mini")
Settings.embed_model = OpenAIEmbedding(model="text-embedding-3-small")
Settings.text_splitter = SentenceSplitter(chunk_size=512, chunk_overlap=30)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from llama_index.core import VectorStoreIndex

index = VectorStoreIndex.from_documents(documents)
query_engine = index.as_query_engine()

# %%
from IPython.display import Markdown, display
def display_response(response):
    display(Markdown(f"<b>{response}</b>"))

# %%
# query = "Explain GraphRAG" # Enter your query here, it should be relevant to the crawled websites
query = "What Matplotlib is?"
res = query_engine.query(query)
display_response(res)

print("-----------------")
# Show the retrieved nodes
for src in res.source_nodes:
  print("Node ID\t", src.node_id)
  print("Title\t", src.metadata['title'])
  print("URL\t", src.metadata['url'])
  print("Score\t", src.score)
  print("Description\t", src.metadata.get("description"))
  print("Category\t", src.metadata.get("category"))
  print("-_"*20)
# Out:
# <b>Matplotlib is a comprehensive library in Python designed for creating static, animated, and interactive visualizations. It serves as a low-level graph plotting utility, making it easier to produce publication-quality plots, interactive figures, and customizable visual styles. Additionally, it allows for exporting to various file formats and embedding in environments like JupyterLab and graphical user interfaces.</b>
# -----------------
# Node ID	 a2940620-23e5-4abe-8d94-dbba0667d805
# Title	 Matplotlib — Visualization with Python
# URL	 https://matplotlib.org/
# Score	 0.6742370120450519
# Description	 Low level graph plotting library in python that serves as a visualization utility
# Category	 Data Visualization
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# Node ID	 dac7692c-85bf-4d32-8c14-5f2ac63deb68
# Title	 Matplotlib — Visualization with Python
# URL	 https://matplotlib.org/
# Score	 0.6400795335687128
# Description	 Low level graph plotting library in python that serves as a visualization utility
# Category	 Data Visualization
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Querying not relevant to the crawled websites.

query = "What is qdrant?"
res = query_engine.query(query)
display_response(res)

print("-----------------")
# Show the retrieved nodes
for src in res.source_nodes:
  print("Node ID\t", src.node_id)
  print("Title\t", src.metadata['title'])
  print("URL\t", src.metadata['url'])
  print("Score\t", src.score)
  print("Description\t", src.metadata.get("description"))
  print("Category\t", src.metadata.get("category"))
  print("-_"*20)
# Out:
# <b>The provided context does not contain any information about "qdrant." Therefore, I cannot provide an answer regarding it.</b>
# -----------------
# Node ID	 4cf1dc1d-4f02-46f3-a761-96f3f7b482ff
# Title	 random_regular_graph — NetworkX 3.5 documentation
# URL	 https://networkx.org/documentation/networkx-3.5/reference/generated/networkx.generators.random_graphs.random_regular_graph.html
# Score	 0.26871881743935244
# Description	 Python package for the creation, manipulation, and study of complex networks
# Category	 Graph Analysis
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# Node ID	 0c57ad42-ffc0-4d16-a85e-5f2e9edc0085
# Title	 NLTK :: nltk package
# URL	 https://www.nltk.org/api/nltk.html
# Score	 0.2612096205711476
# Description	 A suite of libraries and programs for symbolic and statistical natural language processing for English written in the Python programming language
# Category	 Programming Language
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
